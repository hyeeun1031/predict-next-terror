# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl) (2.0.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **1990~2021년 데이터 로드**

# %%
df = pd.read_excel("/content/drive/MyDrive/6조 (final)/data/new/gtd_199902021_summary.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173597 entries, 0 to 173596
# Data columns (total 22 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Unnamed: 0       173597 non-null  int64
#  1   eventid          173597 non-null  int64
#  2   iyear            173597 non-null  int64
#  3   imonth           173597 non-null  int64
#  4   iday             173597 non-null  int64
#  5   country_txt      173597 non-null  object
#  6   region_txt       173597 non-null  object
#  7   provstate        173597 non-null  object
#  8   latitude         171066 non-null  float64
#  9   longitude        171065 non-null  float64
#  10  city             173170 non-null  object
#  11  success          173597 non-null  int64
#  12  summary          147370 non-null  object
#  13  attacktype1_txt  173597 non-null  object
#  14  targtype1_txt    173597 non-null  object
#  15  weaptype1_txt    173597 non-null  object
#  16  nkill            166327 non-null  float64
#  17  nkillter         143536 non-null  float64
#  18  nwound           160387 non-null  float64
#  19  nwoundte         140952 non-null  float64
#  20  natlty1_txt      171728 non-null  object
#  21  gname            173597 non-null  object
# dtypes: float64(6), int64(6), object(10)
# memory usage: 29.1+ MB

# %% [markdown]
# ## **nkill, nwound 결측치 파악**

# %%
columns_to_extract = [
    'eventid',
    'iyear', 'imonth', 'iday',
    'success',
    'country_txt', 'region_txt', 'provstate','city',
    'latitude', 'longitude',
    'attacktype1_txt', 'targtype1_txt', 'natlty1_txt', 'weaptype1_txt',
    'nkill', 'nwound',
    'gname'
]

# %%
# 결측치 건수 계산
null_counts = df[columns_to_extract].isnull().sum()

# 결측치 비율 계산 (백분율로)
null_ratios = (df[columns_to_extract].isnull().mean() * 100).round(2)

# 결과 데이터프레임 생성
null_summary = pd.DataFrame({
    'Null Count': null_counts,
    'Null Ratio (%)': null_ratios
})

null_summary
# Out:
#                  Null Count  Null Ratio (%)
# eventid                   0            0.00
# iyear                     0            0.00
# imonth                    0            0.00
# iday                      0            0.00
# success                   0            0.00
# country_txt               0            0.00
# region_txt                0            0.00
# provstate                 0            0.00
# city                    427            0.25
# latitude               2531            1.46
# longitude              2532            1.46
# attacktype1_txt           0            0.00
# targtype1_txt             0            0.00
# natlty1_txt            1869            1.08
# weaptype1_txt             0            0.00
# nkill                  7270            4.19
# nwound                13210            7.61
# gname                     0            0.00

# %% [markdown]
# ### **success + attacktype 을 기준으로 평균 VS 중앙값 왜도를 비교**

# %%
import pandas as pd
import numpy as np
from scipy.stats import skew

# 복사본 생성
df_mean_fill = df.copy()
df_median_fill = df.copy()

# 평균으로 채우기 (success + attacktype1_txt 조합 기준)
df_mean_fill['nkill'] = df_mean_fill['nkill'].fillna(
    df_mean_fill.groupby(['success', 'attacktype1_txt'])['nkill'].transform('mean')
)
df_mean_fill['nwound'] = df_mean_fill['nwound'].fillna(
    df_mean_fill.groupby(['success', 'attacktype1_txt'])['nwound'].transform('mean')
)

# 중앙값으로 채우기 (success + attacktype1_txt 조합 기준)
df_median_fill['nkill'] = df_median_fill['nkill'].fillna(
    df_median_fill.groupby(['success', 'attacktype1_txt'])['nkill'].transform('median')
)
df_median_fill['nwound'] = df_median_fill['nwound'].fillna(
    df_median_fill.groupby(['success', 'attacktype1_txt'])['nwound'].transform('median')
)

# 요약표 생성: 평균 / 중앙값 / 왜도 비교
summary = pd.DataFrame({
    '기준': ['nkill (원본)', 'nkill (평균)', 'nkill (중앙값)',
           'nwound (원본)', 'nwound (평균)', 'nwound (중앙값)'],
    '평균': [
        np.round(df['nkill'].mean(), 2),
        np.round(df_mean_fill['nkill'].mean(), 2),
        np.round(df_median_fill['nkill'].mean(), 2),
        np.round(df['nwound'].mean(), 2),
        np.round(df_mean_fill['nwound'].mean(), 2),
        np.round(df_median_fill['nwound'].mean(), 2),
    ],
    '중앙값': [
        np.round(df['nkill'].median(), 2),
        np.round(df_mean_fill['nkill'].median(), 2),
        np.round(df_median_fill['nkill'].median(), 2),
        np.round(df['nwound'].median(), 2),
        np.round(df_mean_fill['nwound'].median(), 2),
        np.round(df_median_fill['nwound'].median(), 2),
    ],
    '왜도(Skewness)': [
        np.round(skew(df['nkill'].dropna()), 2),
        np.round(skew(df_mean_fill['nkill']), 2),
        np.round(skew(df_median_fill['nkill']), 2),
        np.round(skew(df['nwound'].dropna()), 2),
        np.round(skew(df_mean_fill['nwound']), 2),
        np.round(skew(df_median_fill['nwound']), 2),
    ]
})

summary
# Out:
#              기준    평균  중앙값  왜도(Skewness)
# 0    nkill (원본)  2.50  1.0         58.75
# 1    nkill (평균)  2.53  1.0         59.95
# 2   nkill (중앙값)  2.41  1.0         59.91
# 3   nwound (원본)  3.35  0.0        202.60
# 4   nwound (평균)  3.31  0.0        210.58
# 5  nwound (중앙값)  3.12  0.0        210.68

# %% [markdown]
# ### **0 구분하는 기준 추가**
# - 0의 비율을 보고 0의 데이터와 0이 아닌 데이터를 나눈 후 success + attacktype 적용
# - 총 3가지의 기준으로 나누어 본다.

# %%
# nkill
nkill_0 = (df['nkill'] == 0).sum()
nkill_nonzero = (df['nkill'] > 0).sum()

# nwound
nwound_0 = (df['nwound'] == 0).sum()
nwound_nonzero = (df['nwound'] > 0).sum()

# %%
print(f"nkill == 0: {nkill_0}건")
print(f"nkill > 0: {nkill_nonzero}건")

print(f"nwound == 0: {nwound_0}건")
print(f"nwound > 0: {nwound_nonzero}건")
# Out:
# nkill == 0: 80402건
# nkill > 0: 85925건
# nwound == 0: 92959건
# nwound > 0: 67428건

# %%
nkill_total = df['nkill'].notnull().sum()
print("nkill 분포")
print(f"nkill == 0   : {nkill_0}건 ({nkill_0 / nkill_total:.2%})")
print(f"nkill > 0    : {nkill_nonzero}건 ({nkill_nonzero / nkill_total:.2%})")
# Out:
# nkill 분포
# nkill == 0   : 80402건 (48.34%)
# nkill > 0    : 85925건 (51.66%)

# %%
nwound_total = df['nwound'].notnull().sum()
print("nwound 분포")
print(f"nwound == 0  : {nwound_0}건 ({nwound_0 / nwound_total:.2%})")
print(f"nwound > 0   : {nwound_nonzero}건 ({nwound_nonzero / nwound_total:.2%})")
# Out:
# nwound 분포
# nwound == 0  : 92959건 (57.96%)
# nwound > 0   : 67428건 (42.04%)

# %% [markdown]
# ### **해석!**
# - 사망자, 부상자 : 0이 차지하는 비율이 비슷하다.
# - 따로 보는 것이 좋겠다 판단.

# %% [markdown]
# ### **0, >0 그룹으로 나누어 본다.**

# %%
from scipy.stats import skew

# 0 vs >0 그룹 생성
def assign_groups(df):
    df['nkill_group'] = np.where(df['nkill'] == 0, '0', '>0')
    df['nwound_group'] = np.where(df['nwound'] == 0, '0', '>0')
    return df

df = assign_groups(df)
df_mean_fill = assign_groups(df_mean_fill)
df_median_fill = assign_groups(df_median_fill)

# 그룹 요약 함수 (평균, 중앙값, 왜도 포함)
def grouped_summary_with_skew(df, var, group_col):
    result = df.groupby(['success', 'attacktype1_txt', group_col])[var].agg(
        평균='mean',
        중앙값='median',
        왜도=lambda x: skew(x.dropna()) if x.dropna().nunique() > 1 else np.nan
    ).reset_index()
    return result

# nkill 요약
nkill_orig = grouped_summary_with_skew(df, 'nkill', 'nkill_group')
nkill_mean = grouped_summary_with_skew(df_mean_fill, 'nkill', 'nkill_group')
nkill_median = grouped_summary_with_skew(df_median_fill, 'nkill', 'nkill_group')

# nwound 요약
nwound_orig = grouped_summary_with_skew(df, 'nwound', 'nwound_group')
nwound_mean = grouped_summary_with_skew(df_mean_fill, 'nwound', 'nwound_group')
nwound_median = grouped_summary_with_skew(df_median_fill, 'nwound', 'nwound_group')

# %%
print("📌 nkill (원본)")
display(nkill_orig)

print("📌 nkill (평균 대체)")
display(nkill_mean)

print("📌 nkill (중앙값 대체)")
display(nkill_median)

print("📌 nwound (원본)")
display(nwound_orig)

print("📌 nwound (평균 대체)")
display(nwound_mean)

print("📌 nwound (중앙값 대체)")
display(nwound_median)
# Out:
# 📌 nkill (원본)
#     success                      attacktype1_txt nkill_group         평균  중앙값  \
# 0         0                        Armed Assault           0   0.000000  0.0
# 1         0                        Armed Assault          >0   4.561111  2.0
# 2         0                        Assassination           0   0.000000  0.0
# 3         0                        Assassination          >0   2.855385  2.0
# 4         0                    Bombing/Explosion           0   0.000000  0.0
# 5         0                    Bombing/Explosion          >0   4.366448  2.0
# 6         0       Facility/Infrastructure Attack           0   0.000000  0.0
# 7         0       Facility/Infrastructure Attack          >0   4.937500  2.5
# 8         0                            Hijacking           0   0.000000  0.0
# 9         0                            Hijacking          >0   2.750000  2.0
# 10        0  Hostage Taking (Barricade Incident)           0   0.000000  0.0
# 11        0  Hostage Taking (Barricade Incident)          >0   3.000000  1.0
# 12        0          Hostage Taking (Kidnapping)           0   0.000000  0.0
# 13        0          Hostage Taking (Kidnapping)          >0   2.098361  1.0
# 14        0                      Unarmed Assault           0   0.000000  0.0
# 15        0                      Unarmed Assault          >0   1.000000  1.0
# 16        0                              Unknown           0   0.000000  0.0
# 17        0                              Unknown          >0   8.254818  5.0
# 18        1                        Armed Assault           0   0.000000  0.0
# 19        1                        Armed Assault          >0   4.940695  2.0
# 20        1                        Assassination           0   0.000000  0.0
# 21        1                        Assassination          >0   1.627900  1.0
# 22        1                    Bombing/Explosion           0   0.000000  0.0
# 23        1                    Bombing/Explosion          >0   4.912305  2.0
# 24        1       Facility/Infrastructure Attack           0   0.000000  0.0
# 25        1       Facility/Infrastructure Attack          >0   5.920962  2.0
# 26        1                            Hijacking           0   0.000000  0.0
# 27        1                            Hijacking          >0  33.707071  2.0
# 28        1  Hostage Taking (Barricade Incident)           0   0.000000  0.0
# 29        1  Hostage Taking (Barricade Incident)          >0  18.763265  6.0
# 30        1          Hostage Taking (Kidnapping)           0   0.000000  0.0
# 31        1          Hostage Taking (Kidnapping)          >0   6.954246  2.0
# 32        1                      Unarmed Assault           0   0.000000  0.0
# 33        1                      Unarmed Assault          >0   4.434343  1.0
# 34        1                              Unknown           0   0.000000  0.0
# 35        1                              Unknown          >0   6.498657  3.0
#
#            왜도
# 0         NaN
# 1    3.838476
# 2         NaN
# 3    4.247923
# 4         NaN
# 5    6.018815
# 6         NaN
# 7    2.742176
# 8         NaN
# 9    1.550540
# 10        NaN
# 11   0.707107
# 12        NaN
# 13   4.789194
# 14        NaN
# 15        NaN
# 16        NaN
# 17   5.753516
# 18        NaN
# 19  31.928821
# 20        NaN
# 21   8.902592
# 22        NaN
# 23  15.720268
# 24        NaN
# 25  17.391708
# 26        NaN
# 27   6.719453
# 28        NaN
# 29   4.631002
# 30        NaN
# 31  27.866912
# 32        NaN
# 33   9.523517
# 34        NaN
# 35  13.620204
# 📌 nkill (평균 대체)
#     success                      attacktype1_txt nkill_group         평균  \
# 0         0                        Armed Assault           0   0.000000
# 1         0                        Armed Assault          >0   4.094587
# 2         0                        Assassination           0   0.000000
# 3         0                        Assassination          >0   2.764991
# 4         0                    Bombing/Explosion           0   0.000000
# 5         0                    Bombing/Explosion          >0   4.013473
# 6         0       Facility/Infrastructure Attack           0   0.000000
# 7         0       Facility/Infrastructure Attack          >0   4.184953
# 8         0                            Hijacking           0   0.000000
# 9         0                            Hijacking          >0   2.576923
# 10        0  Hostage Taking (Barricade Incident)           0   0.000000
# 11        0  Hostage Taking (Barricade Incident)          >0   2.700000
# 12        0          Hostage Taking (Kidnapping)           0   0.000000
# 13        0          Hostage Taking (Kidnapping)          >0   1.938423
# 14        0                      Unarmed Assault           0   0.000000
# 15        0                      Unarmed Assault          >0   1.000000
# 16        0                              Unknown           0   0.000000
# 17        0                              Unknown          >0   7.170694
# 18        1                        Armed Assault           0   0.000000
# 19        1                        Armed Assault          >0   4.900275
# 20        1                        Assassination           0   0.000000
# 21        1                        Assassination          >0   1.627846
# 22        1                    Bombing/Explosion           0   0.000000
# 23        1                    Bombing/Explosion          >0   4.800535
# 24        1       Facility/Infrastructure Attack           0   0.000000
# 25        1       Facility/Infrastructure Attack          >0   4.598712
# 26        1                            Hijacking           0   0.000000
# 27        1                            Hijacking          >0  23.455065
# 28        1  Hostage Taking (Barricade Incident)           0   0.000000
# 29        1  Hostage Taking (Barricade Incident)          >0  17.693086
# 30        1          Hostage Taking (Kidnapping)           0   0.000000
# 31        1          Hostage Taking (Kidnapping)          >0   5.554098
# 32        1                      Unarmed Assault           0   0.000000
# 33        1                      Unarmed Assault          >0   4.245996
# 34        1                              Unknown           0   0.000000
# 35        1                              Unknown          >0   6.355549
#
#          중앙값         왜도
# 0   0.000000        NaN
# 1   2.000000   4.129865
# 2   0.000000        NaN
# 3   2.000000   4.307895
# 4   0.000000        NaN
# 5   2.000000   6.236476
# 6   0.000000        NaN
# 7   2.000000   2.976006
# 8   0.000000        NaN
# 9   2.000000   1.614906
# 10  0.000000        NaN
# 11  1.400000   1.097958
# 12  0.000000        NaN
# 13  1.000000   4.894725
# 14  0.000000        NaN
# 15  1.000000        NaN
# 16  0.000000        NaN
# 17  4.252620   6.727866
# 18  0.000000        NaN
# 19  2.000000  32.479091
# 20  0.000000        NaN
# 21  1.000000   8.910203
# 22  0.000000        NaN
# 23  2.000000  16.033860
# 24  0.000000        NaN
# 25  1.000000  19.530140
# 26  0.000000        NaN
# 27  5.000000   8.676249
# 28  0.000000        NaN
# 29  7.205329   4.884684
# 30  0.000000        NaN
# 31  3.451415  35.921635
# 32  0.000000        NaN
# 33  1.000000   9.782868
# 34  0.000000        NaN
# 35  4.000000  14.520629
# 📌 nkill (중앙값 대체)
#     success                      attacktype1_txt nkill_group         평균  중앙값  \
# 0         0                        Armed Assault           0   0.000000  0.0
# 1         0                        Armed Assault          >0   4.561111  2.0
# 2         0                        Assassination           0   0.000000  0.0
# 3         0                        Assassination          >0   2.855385  2.0
# 4         0                    Bombing/Explosion           0   0.000000  0.0
# 5         0                    Bombing/Explosion          >0   4.366448  2.0
# 6         0       Facility/Infrastructure Attack           0   0.000000  0.0
# 7         0       Facility/Infrastructure Attack          >0   4.937500  2.5
# 8         0                            Hijacking           0   0.000000  0.0
# 9         0                            Hijacking          >0   2.750000  2.0
# 10        0  Hostage Taking (Barricade Incident)           0   0.000000  0.0
# 11        0  Hostage Taking (Barricade Incident)          >0   2.500000  1.0
# 12        0          Hostage Taking (Kidnapping)           0   0.000000  0.0
# 13        0          Hostage Taking (Kidnapping)          >0   2.098361  1.0
# 14        0                      Unarmed Assault           0   0.000000  0.0
# 15        0                      Unarmed Assault          >0   1.000000  1.0
# 16        0                              Unknown           0   0.000000  0.0
# 17        0                              Unknown          >0   6.289617  3.0
# 18        1                        Armed Assault           0   0.000000  0.0
# 19        1                        Armed Assault          >0   4.807513  2.0
# 20        1                        Assassination           0   0.000000  0.0
# 21        1                        Assassination          >0   1.626839  1.0
# 22        1                    Bombing/Explosion           0   0.000000  0.0
# 23        1                    Bombing/Explosion          >0   4.912305  2.0
# 24        1       Facility/Infrastructure Attack           0   0.000000  0.0
# 25        1       Facility/Infrastructure Attack          >0   5.920962  2.0
# 26        1                            Hijacking           0   0.000000  0.0
# 27        1                            Hijacking          >0  33.707071  2.0
# 28        1  Hostage Taking (Barricade Incident)           0   0.000000  0.0
# 29        1  Hostage Taking (Barricade Incident)          >0  18.763265  6.0
# 30        1          Hostage Taking (Kidnapping)           0   0.000000  0.0
# 31        1          Hostage Taking (Kidnapping)          >0   6.954246  2.0
# 32        1                      Unarmed Assault           0   0.000000  0.0
# 33        1                      Unarmed Assault          >0   4.434343  1.0
# 34        1                              Unknown           0   0.000000  0.0
# 35        1                              Unknown          >0   5.964782  3.0
#
#            왜도
# 0         NaN
# 1    3.838476
# 2         NaN
# 3    4.247923
# 4         NaN
# 5    6.018815
# 6         NaN
# 7    2.742176
# 8         NaN
# 9    1.550540
# 10        NaN
# 11   1.154701
# 12        NaN
# 13   4.789194
# 14        NaN
# 15        NaN
# 16        NaN
# 17   6.256686
# 18        NaN
# 19  32.378821
# 20        NaN
# 21   8.909233
# 22        NaN
# 23  15.720268
# 24        NaN
# 25  17.391708
# 26        NaN
# 27   6.719453
# 28        NaN
# 29   4.631002
# 30        NaN
# 31  27.866912
# 32        NaN
# 33   9.523517
# 34        NaN
# 35  14.306050
# 📌 nwound (원본)
#     success                      attacktype1_txt nwound_group          평균  \
# 0         0                        Armed Assault            0    0.000000
# 1         0                        Armed Assault           >0    4.484009
# 2         0                        Assassination            0    0.000000
# 3         0                        Assassination           >0    2.948238
# 4         0                    Bombing/Explosion            0    0.000000
# 5         0                    Bombing/Explosion           >0    6.221184
# 6         0       Facility/Infrastructure Attack            0    0.000000
# 7         0       Facility/Infrastructure Attack           >0    1.384615
# 8         0                            Hijacking            0    0.000000
# 9         0                            Hijacking           >0    3.750000
# 10        0  Hostage Taking (Barricade Incident)            0    0.000000
# 11        0  Hostage Taking (Barricade Incident)           >0    3.000000
# 12        0          Hostage Taking (Kidnapping)            0    0.000000
# 13        0          Hostage Taking (Kidnapping)           >0    1.962025
# 14        0                      Unarmed Assault            0    0.000000
# 15        0                      Unarmed Assault           >0    1.230769
# 16        0                              Unknown            0    0.000000
# 17        0                              Unknown           >0    5.348131
# 18        1                        Armed Assault            0    0.000000
# 19        1                        Armed Assault           >0    4.806981
# 20        1                        Assassination            0    0.000000
# 21        1                        Assassination           >0    3.731449
# 22        1                    Bombing/Explosion            0    0.000000
# 23        1                    Bombing/Explosion           >0    9.394429
# 24        1       Facility/Infrastructure Attack            0    0.000000
# 25        1       Facility/Infrastructure Attack           >0    6.377224
# 26        1                            Hijacking            0    0.000000
# 27        1                            Hijacking           >0  294.573333
# 28        1  Hostage Taking (Barricade Incident)            0    0.000000
# 29        1  Hostage Taking (Barricade Incident)           >0   20.105769
# 30        1          Hostage Taking (Kidnapping)            0    0.000000
# 31        1          Hostage Taking (Kidnapping)           >0    6.096689
# 32        1                      Unarmed Assault            0    0.000000
# 33        1                      Unarmed Assault           >0   20.951442
# 34        1                              Unknown            0    0.000000
# 35        1                              Unknown           >0    5.742044
#
#     중앙값         왜도
# 0   0.0        NaN
# 1   2.0   3.825566
# 2   0.0        NaN
# 3   1.0   8.686328
# 4   0.0        NaN
# 5   2.0   6.067350
# 6   0.0        NaN
# 7   1.0   1.387577
# 8   0.0        NaN
# 9   2.0   2.194625
# 10  0.0        NaN
# 11  3.0        NaN
# 12  0.0        NaN
# 13  1.0   2.263157
# 14  0.0        NaN
# 15  1.0   2.362398
# 16  0.0        NaN
# 17  3.0   3.702371
# 18  0.0        NaN
# 19  2.0  35.450156
# 20  0.0        NaN
# 21  2.0  14.693731
# 22  0.0        NaN
# 23  4.0  64.954432
# 24  0.0        NaN
# 25  2.0   7.152346
# 26  0.0        NaN
# 27  2.0   5.875534
# 28  0.0        NaN
# 29  4.0   8.700381
# 30  0.0        NaN
# 31  2.0  16.138994
# 32  0.0        NaN
# 33  2.0  24.060752
# 34  0.0        NaN
# 35  3.0   9.237829
# 📌 nwound (평균 대체)
#     success                      attacktype1_txt nwound_group          평균  \
# 0         0                        Armed Assault            0    0.000000
# 1         0                        Armed Assault           >0    3.173358
# 2         0                        Assassination            0    0.000000
# 3         0                        Assassination           >0    2.906021
# 4         0                    Bombing/Explosion            0    0.000000
# 5         0                    Bombing/Explosion           >0    4.608256
# 6         0       Facility/Infrastructure Attack            0    0.000000
# 7         0       Facility/Infrastructure Attack           >0    0.739115
# 8         0                            Hijacking            0    0.000000
# 9         0                            Hijacking           >0    3.513986
# 10        0  Hostage Taking (Barricade Incident)            0    0.000000
# 11        0  Hostage Taking (Barricade Incident)           >0    3.000000
# 12        0          Hostage Taking (Kidnapping)            0    0.000000
# 13        0          Hostage Taking (Kidnapping)           >0    1.816641
# 14        0                      Unarmed Assault            0    0.000000
# 15        0                      Unarmed Assault           >0    1.080984
# 16        0                              Unknown            0    0.000000
# 17        0                              Unknown           >0    3.307936
# 18        1                        Armed Assault            0    0.000000
# 19        1                        Armed Assault           >0    4.392652
# 20        1                        Assassination            0    0.000000
# 21        1                        Assassination           >0    3.273231
# 22        1                    Bombing/Explosion            0    0.000000
# 23        1                    Bombing/Explosion           >0    9.112636
# 24        1       Facility/Infrastructure Attack            0    0.000000
# 25        1       Facility/Infrastructure Attack           >0    4.158560
# 26        1                            Hijacking            0    0.000000
# 27        1                            Hijacking           >0  175.401341
# 28        1  Hostage Taking (Barricade Incident)            0    0.000000
# 29        1  Hostage Taking (Barricade Incident)           >0   16.455968
# 30        1          Hostage Taking (Kidnapping)            0    0.000000
# 31        1          Hostage Taking (Kidnapping)           >0    2.453655
# 32        1                      Unarmed Assault            0    0.000000
# 33        1                      Unarmed Assault           >0   20.132454
# 34        1                              Unknown            0    0.000000
# 35        1                              Unknown           >0    4.981527
#
#           중앙값         왜도
# 0    0.000000        NaN
# 1    1.000000   4.625100
# 2    0.000000        NaN
# 3    1.000000   8.853012
# 4    0.000000        NaN
# 5    1.000000   6.995085
# 6    0.000000        NaN
# 7    1.000000   1.029483
# 8    0.000000        NaN
# 9    2.000000   2.318001
# 10   0.000000        NaN
# 11   3.000000        NaN
# 12   0.000000        NaN
# 13   1.000000   2.371008
# 14   0.000000        NaN
# 15   1.000000   1.401859
# 16   0.000000        NaN
# 17   1.332363   5.038239
# 18   0.000000        NaN
# 19   2.216393  38.521513
# 20   0.000000        NaN
# 21   1.000000  15.777293
# 22   0.000000        NaN
# 23   4.000000  67.276512
# 24   0.000000        NaN
# 25   1.000000   8.806746
# 26   0.000000        NaN
# 27  47.717063   8.333188
# 28   0.000000        NaN
# 29   7.197935  10.282692
# 30   0.000000        NaN
# 31   1.066620  30.129745
# 32   0.000000        NaN
# 33   2.000000  25.829788
# 34   0.000000        NaN
# 35   3.028818  10.829344
# 📌 nwound (중앙값 대체)
#     success                      attacktype1_txt nwound_group          평균  \
# 0         0                        Armed Assault            0    0.000000
# 1         0                        Armed Assault           >0    4.484009
# 2         0                        Assassination            0    0.000000
# 3         0                        Assassination           >0    2.876591
# 4         0                    Bombing/Explosion            0    0.000000
# 5         0                    Bombing/Explosion           >0    6.221184
# 6         0       Facility/Infrastructure Attack            0    0.000000
# 7         0       Facility/Infrastructure Attack           >0    1.384615
# 8         0                            Hijacking            0    0.000000
# 9         0                            Hijacking           >0    3.750000
# 10        0  Hostage Taking (Barricade Incident)            0    0.000000
# 11        0  Hostage Taking (Barricade Incident)           >0    3.000000
# 12        0          Hostage Taking (Kidnapping)            0    0.000000
# 13        0          Hostage Taking (Kidnapping)           >0    1.962025
# 14        0                      Unarmed Assault            0    0.000000
# 15        0                      Unarmed Assault           >0    1.230769
# 16        0                              Unknown            0    0.000000
# 17        0                              Unknown           >0    5.348131
# 18        1                        Armed Assault            0    0.000000
# 19        1                        Armed Assault           >0    4.806981
# 20        1                        Assassination            0    0.000000
# 21        1                        Assassination           >0    3.731449
# 22        1                    Bombing/Explosion            0    0.000000
# 23        1                    Bombing/Explosion           >0    8.803553
# 24        1       Facility/Infrastructure Attack            0    0.000000
# 25        1       Facility/Infrastructure Attack           >0    6.377224
# 26        1                            Hijacking            0    0.000000
# 27        1                            Hijacking           >0  294.573333
# 28        1  Hostage Taking (Barricade Incident)            0    0.000000
# 29        1  Hostage Taking (Barricade Incident)           >0   20.105769
# 30        1          Hostage Taking (Kidnapping)            0    0.000000
# 31        1          Hostage Taking (Kidnapping)           >0    6.096689
# 32        1                      Unarmed Assault            0    0.000000
# 33        1                      Unarmed Assault           >0   18.322793
# 34        1                              Unknown            0    0.000000
# 35        1                              Unknown           >0    4.412850
#
#     중앙값         왜도
# 0   0.0        NaN
# 1   2.0   3.825566
# 2   0.0        NaN
# 3   1.0   8.830123
# 4   0.0        NaN
# 5   2.0   6.067350
# 6   0.0        NaN
# 7   1.0   1.387577
# 8   0.0        NaN
# 9   2.0   2.194625
# 10  0.0        NaN
# 11  3.0        NaN
# 12  0.0        NaN
# 13  1.0   2.263157
# 14  0.0        NaN
# 15  1.0   2.362398
# 16  0.0        NaN
# 17  3.0   3.702371
# 18  0.0        NaN
# 19  2.0  35.450156
# 20  0.0        NaN
# 21  2.0  14.693731
# 22  0.0        NaN
# 23  4.0  66.899507
# 24  0.0        NaN
# 25  2.0   7.152346
# 26  0.0        NaN
# 27  2.0   5.875534
# 28  0.0        NaN
# 29  4.0   8.700381
# 30  0.0        NaN
# 31  2.0  16.138994
# 32  0.0        NaN
# 33  1.0  25.817912
# 34  0.0        NaN
# 35  2.0  10.388833

# %%
# 복사: 원본, 평균 대체, 중앙값 대체에 "대체방법" 열 추가
nkill_orig['대체방법'] = '원본'
nkill_mean['대체방법'] = '평균 대체'
nkill_median['대체방법'] = '중앙값 대체'

# 세 개를 하나로 세로 병합
nkill_combined = pd.concat([nkill_orig, nkill_mean, nkill_median], ignore_index=True)

# 열 순서 정리
nkill_combined = nkill_combined[['대체방법', 'success', 'attacktype1_txt', 'nkill_group', '평균', '중앙값', '왜도']]

# %%
for attack_type in nkill_combined['attacktype1_txt'].unique():
  print(f"\n📌 공격 유형: {attack_type}")
  display(nkill_combined[nkill_combined['attacktype1_txt'] == attack_type])
# Out:
# 📌 공격 유형: Armed Assault
#       대체방법  success attacktype1_txt nkill_group        평균  중앙값         왜도
# 0       원본        0   Armed Assault           0  0.000000  0.0        NaN
# 1       원본        0   Armed Assault          >0  4.561111  2.0   3.838476
# 18      원본        1   Armed Assault           0  0.000000  0.0        NaN
# 19      원본        1   Armed Assault          >0  4.940695  2.0  31.928821
# 36   평균 대체        0   Armed Assault           0  0.000000  0.0        NaN
# 37   평균 대체        0   Armed Assault          >0  4.094587  2.0   4.129865
# 54   평균 대체        1   Armed Assault           0  0.000000  0.0        NaN
# 55   평균 대체        1   Armed Assault          >0  4.900275  2.0  32.479091
# 72  중앙값 대체        0   Armed Assault           0  0.000000  0.0        NaN
# 73  중앙값 대체        0   Armed Assault          >0  4.561111  2.0   3.838476
# 90  중앙값 대체        1   Armed Assault           0  0.000000  0.0        NaN
# 91  중앙값 대체        1   Armed Assault          >0  4.807513  2.0  32.378821
# 📌 공격 유형: Assassination
#       대체방법  success attacktype1_txt nkill_group        평균  중앙값        왜도
# 2       원본        0   Assassination           0  0.000000  0.0       NaN
# 3       원본        0   Assassination          >0  2.855385  2.0  4.247923
# 20      원본        1   Assassination           0  0.000000  0.0       NaN
# 21      원본        1   Assassination          >0  1.627900  1.0  8.902592
# 38   평균 대체        0   Assassination           0  0.000000  0.0       NaN
# 39   평균 대체        0   Assassination          >0  2.764991  2.0  4.307895
# 56   평균 대체        1   Assassination           0  0.000000  0.0       NaN
# 57   평균 대체        1   Assassination          >0  1.627846  1.0  8.910203
# 74  중앙값 대체        0   Assassination           0  0.000000  0.0       NaN
# 75  중앙값 대체        0   Assassination          >0  2.855385  2.0  4.247923
# 92  중앙값 대체        1   Assassination           0  0.000000  0.0       NaN
# 93  중앙값 대체        1   Assassination          >0  1.626839  1.0  8.909233
# 📌 공격 유형: Bombing/Explosion
#       대체방법  success    attacktype1_txt nkill_group        평균  중앙값         왜도
# 4       원본        0  Bombing/Explosion           0  0.000000  0.0        NaN
# 5       원본        0  Bombing/Explosion          >0  4.366448  2.0   6.018815
# 22      원본        1  Bombing/Explosion           0  0.000000  0.0        NaN
# 23      원본        1  Bombing/Explosion          >0  4.912305  2.0  15.720268
# 40   평균 대체        0  Bombing/Explosion           0  0.000000  0.0        NaN
# 41   평균 대체        0  Bombing/Explosion          >0  4.013473  2.0   6.236476
# 58   평균 대체        1  Bombing/Explosion           0  0.000000  0.0        NaN
# 59   평균 대체        1  Bombing/Explosion          >0  4.800535  2.0  16.033860
# 76  중앙값 대체        0  Bombing/Explosion           0  0.000000  0.0        NaN
# 77  중앙값 대체        0  Bombing/Explosion          >0  4.366448  2.0   6.018815
# 94  중앙값 대체        1  Bombing/Explosion           0  0.000000  0.0        NaN
# 95  중앙값 대체        1  Bombing/Explosion          >0  4.912305  2.0  15.720268
# 📌 공격 유형: Facility/Infrastructure Attack
#       대체방법  success                 attacktype1_txt nkill_group        평균  \
# 6       원본        0  Facility/Infrastructure Attack           0  0.000000
# 7       원본        0  Facility/Infrastructure Attack          >0  4.937500
# 24      원본        1  Facility/Infrastructure Attack           0  0.000000
# 25      원본        1  Facility/Infrastructure Attack          >0  5.920962
# 42   평균 대체        0  Facility/Infrastructure Attack           0  0.000000
# 43   평균 대체        0  Facility/Infrastructure Attack          >0  4.184953
# 60   평균 대체        1  Facility/Infrastructure Attack           0  0.000000
# 61   평균 대체        1  Facility/Infrastructure Attack          >0  4.598712
# 78  중앙값 대체        0  Facility/Infrastructure Attack           0  0.000000
# 79  중앙값 대체        0  Facility/Infrastructure Attack          >0  4.937500
# 96  중앙값 대체        1  Facility/Infrastructure Attack           0  0.000000
# 97  중앙값 대체        1  Facility/Infrastructure Attack          >0  5.920962
#
#     중앙값         왜도
# 6   0.0        NaN
# 7   2.5   2.742176
# 24  0.0        NaN
# 25  2.0  17.391708
# 42  0.0        NaN
# 43  2.0   2.976006
# 60  0.0        NaN
# 61  1.0  19.530140
# 78  0.0        NaN
# 79  2.5   2.742176
# 96  0.0        NaN
# 97  2.0  17.391708
# 📌 공격 유형: Hijacking
#       대체방법  success attacktype1_txt nkill_group         평균  중앙값        왜도
# 8       원본        0       Hijacking           0   0.000000  0.0       NaN
# 9       원본        0       Hijacking          >0   2.750000  2.0  1.550540
# 26      원본        1       Hijacking           0   0.000000  0.0       NaN
# 27      원본        1       Hijacking          >0  33.707071  2.0  6.719453
# 44   평균 대체        0       Hijacking           0   0.000000  0.0       NaN
# 45   평균 대체        0       Hijacking          >0   2.576923  2.0  1.614906
# 62   평균 대체        1       Hijacking           0   0.000000  0.0       NaN
# 63   평균 대체        1       Hijacking          >0  23.455065  5.0  8.676249
# 80  중앙값 대체        0       Hijacking           0   0.000000  0.0       NaN
# 81  중앙값 대체        0       Hijacking          >0   2.750000  2.0  1.550540
# 98  중앙값 대체        1       Hijacking           0   0.000000  0.0       NaN
# 99  중앙값 대체        1       Hijacking          >0  33.707071  2.0  6.719453
# 📌 공격 유형: Hostage Taking (Barricade Incident)
#        대체방법  success                      attacktype1_txt nkill_group  \
# 10       원본        0  Hostage Taking (Barricade Incident)           0
# 11       원본        0  Hostage Taking (Barricade Incident)          >0
# 28       원본        1  Hostage Taking (Barricade Incident)           0
# 29       원본        1  Hostage Taking (Barricade Incident)          >0
# 46    평균 대체        0  Hostage Taking (Barricade Incident)           0
# 47    평균 대체        0  Hostage Taking (Barricade Incident)          >0
# 64    평균 대체        1  Hostage Taking (Barricade Incident)           0
# 65    평균 대체        1  Hostage Taking (Barricade Incident)          >0
# 82   중앙값 대체        0  Hostage Taking (Barricade Incident)           0
# 83   중앙값 대체        0  Hostage Taking (Barricade Incident)          >0
# 100  중앙값 대체        1  Hostage Taking (Barricade Incident)           0
# 101  중앙값 대체        1  Hostage Taking (Barricade Incident)          >0
#
#             평균       중앙값        왜도
# 10    0.000000  0.000000       NaN
# 11    3.000000  1.000000  0.707107
# 28    0.000000  0.000000       NaN
# 29   18.763265  6.000000  4.631002
# 46    0.000000  0.000000       NaN
# 47    2.700000  1.400000  1.097958
# 64    0.000000  0.000000       NaN
# 65   17.693086  7.205329  4.884684
# 82    0.000000  0.000000       NaN
# 83    2.500000  1.000000  1.154701
# 100   0.000000  0.000000       NaN
# 101  18.763265  6.000000  4.631002
# 📌 공격 유형: Hostage Taking (Kidnapping)
#        대체방법  success              attacktype1_txt nkill_group        평균  \
# 12       원본        0  Hostage Taking (Kidnapping)           0  0.000000
# 13       원본        0  Hostage Taking (Kidnapping)          >0  2.098361
# 30       원본        1  Hostage Taking (Kidnapping)           0  0.000000
# 31       원본        1  Hostage Taking (Kidnapping)          >0  6.954246
# 48    평균 대체        0  Hostage Taking (Kidnapping)           0  0.000000
# 49    평균 대체        0  Hostage Taking (Kidnapping)          >0  1.938423
# 66    평균 대체        1  Hostage Taking (Kidnapping)           0  0.000000
# 67    평균 대체        1  Hostage Taking (Kidnapping)          >0  5.554098
# 84   중앙값 대체        0  Hostage Taking (Kidnapping)           0  0.000000
# 85   중앙값 대체        0  Hostage Taking (Kidnapping)          >0  2.098361
# 102  중앙값 대체        1  Hostage Taking (Kidnapping)           0  0.000000
# 103  중앙값 대체        1  Hostage Taking (Kidnapping)          >0  6.954246
#
#           중앙값         왜도
# 12   0.000000        NaN
# 13   1.000000   4.789194
# 30   0.000000        NaN
# 31   2.000000  27.866912
# 48   0.000000        NaN
# 49   1.000000   4.894725
# 66   0.000000        NaN
# 67   3.451415  35.921635
# 84   0.000000        NaN
# 85   1.000000   4.789194
# 102  0.000000        NaN
# 103  2.000000  27.866912
# 📌 공격 유형: Unarmed Assault
#        대체방법  success  attacktype1_txt nkill_group        평균  중앙값        왜도
# 14       원본        0  Unarmed Assault           0  0.000000  0.0       NaN
# 15       원본        0  Unarmed Assault          >0  1.000000  1.0       NaN
# 32       원본        1  Unarmed Assault           0  0.000000  0.0       NaN
# 33       원본        1  Unarmed Assault          >0  4.434343  1.0  9.523517
# 50    평균 대체        0  Unarmed Assault           0  0.000000  0.0       NaN
# 51    평균 대체        0  Unarmed Assault          >0  1.000000  1.0       NaN
# 68    평균 대체        1  Unarmed Assault           0  0.000000  0.0       NaN
# 69    평균 대체        1  Unarmed Assault          >0  4.245996  1.0  9.782868
# 86   중앙값 대체        0  Unarmed Assault           0  0.000000  0.0       NaN
# 87   중앙값 대체        0  Unarmed Assault          >0  1.000000  1.0       NaN
# 104  중앙값 대체        1  Unarmed Assault           0  0.000000  0.0       NaN
# 105  중앙값 대체        1  Unarmed Assault          >0  4.434343  1.0  9.523517
# 📌 공격 유형: Unknown
#        대체방법  success attacktype1_txt nkill_group        평균      중앙값         왜도
# 16       원본        0         Unknown           0  0.000000  0.00000        NaN
# 17       원본        0         Unknown          >0  8.254818  5.00000   5.753516
# 34       원본        1         Unknown           0  0.000000  0.00000        NaN
# 35       원본        1         Unknown          >0  6.498657  3.00000  13.620204
# 52    평균 대체        0         Unknown           0  0.000000  0.00000        NaN
# 53    평균 대체        0         Unknown          >0  7.170694  4.25262   6.727866
# 70    평균 대체        1         Unknown           0  0.000000  0.00000        NaN
# 71    평균 대체        1         Unknown          >0  6.355549  4.00000  14.520629
# 88   중앙값 대체        0         Unknown           0  0.000000  0.00000        NaN
# 89   중앙값 대체        0         Unknown          >0  6.289617  3.00000   6.256686
# 106  중앙값 대체        1         Unknown           0  0.000000  0.00000        NaN
# 107  중앙값 대체        1         Unknown          >0  5.964782  3.00000  14.306050

# %% [markdown]
# ### **해석!**
# - 전체적으로 중앙값으로 대체하는 것이 원본과 왜도가 비슷하다고 판단.

# %% [markdown]
# ## **nkill, nwound 결측치 대체**

# %%
df['nkill'] = df['nkill'].fillna(
    df.groupby(['success', 'attacktype1_txt'])['nkill']
      .transform(lambda x: x[x > 0].median() if (x > 0).any() else 0)
)

df['nwound'] = df['nwound'].fillna(
    df.groupby(['success', 'attacktype1_txt'])['nwound']
      .transform(lambda x: x[x > 0].median() if (x > 0).any() else 0)
)

# %%
df[columns_to_extract].isnull().sum()
# Out:
# eventid               0
# iyear                 0
# imonth                0
# iday                  0
# success               0
# country_txt           0
# region_txt            0
# provstate             0
# city                427
# latitude           2531
# longitude          2532
# attacktype1_txt       0
# targtype1_txt         0
# natlty1_txt        1869
# weaptype1_txt         0
# nkill                 0
# nwound                0
# gname                 0
# dtype: int64

# %% [markdown]
# ## **natlty1_txt 대체**

# %%
df[df['natlty1_txt'].isnull()]
# Out:
#         Unnamed: 0       eventid  iyear  imonth  iday         country_txt  \
# 1415         42484  199005140008   1990       5    14        South Africa
# 1835         42904  199006090020   1990       6     9               India
# 1906         42975  199006150008   1990       6    15  East Germany (GDR)
# 4663         45732  199103090001   1991       3     9         Philippines
# 4679         45748  199103100011   1991       3    10          Mozambique
# ...            ...           ...    ...     ...   ...                 ...
# 172732      213801  202105260015   2021       5    26         Afghanistan
# 173045      214114  202106090002   2021       6     9         Afghanistan
# 173191      214260  202106160017   2021       6    16              Israel
# 173512      214581  202106270046   2021       6    26         Afghanistan
# 173531      214600  202106280014   2021       6    27         Afghanistan
#
#                         region_txt             provstate   latitude  \
# 1415            Sub-Saharan Africa            Mpumalanga -26.102892
# 1835                    South Asia                Punjab  31.633979
# 1906                Eastern Europe                Berlin  52.501530
# 4663                Southeast Asia  Metropolitian Manila  14.596051
# 4679            Sub-Saharan Africa                  Gaza -23.022193
# ...                            ...                   ...        ...
# 172732                  South Asia                Ghazni  33.675278
# 173045                  South Asia               Badghis  34.855085
# 173191  Middle East & North Africa              Southern  31.296742
# 173512                  South Asia                Kunduz  36.538299
# 173531                  South Asia                 Khost  33.381111
#
#          longitude  ...                   targtype1_txt  weaptype1_txt nkill  \
# 1415     28.698275  ...     Private Citizens & Property     Incendiary   0.0
# 1835     74.872264  ...                          Police       Firearms   1.0
# 1906     13.401851  ...     Private Citizens & Property        Unknown   0.0
# 4663    120.978666  ...  Religious Figures/Institutions     Explosives   2.0
# 4679     32.718138  ...            Food or Water Supply       Firearms  25.0
# ...            ...  ...                             ...            ...   ...
# 172732   68.421667  ...                         Unknown     Explosives   0.0
# 173045   63.486204  ...                         Unknown     Explosives   2.0
# 173191   34.413408  ...                         Unknown     Incendiary   0.0
# 173512   68.888879  ...                         Unknown     Explosives   6.0
# 173531   69.682500  ...                         Unknown     Explosives   0.0
#
#        nkillter nwound nwoundte  natlty1_txt  \
# 1415        NaN    0.0      NaN          NaN
# 1835        NaN    0.0      NaN          NaN
# 1906        NaN    0.0      NaN          NaN
# 4663        NaN    2.0      NaN          NaN
# 4679        NaN   19.0      NaN          NaN
# ...         ...    ...      ...          ...
# 172732      0.0    0.0      0.0          NaN
# 173045      0.0    0.0      0.0          NaN
# 173191      0.0    0.0      0.0          NaN
# 173512      6.0    0.0      0.0          NaN
# 173531      0.0    0.0      0.0          NaN
#
#                                                 gname  nkill_group  \
# 1415                                          Unknown            0
# 1835                                          Unknown           >0
# 1906                              Neo-Nazi extremists            0
# 4663                             Pro-Iraqi Terrorists           >0
# 4679    Mozambique National Resistance Movement (MNR)           >0
# ...                                               ...          ...
# 172732                                        Unknown            0
# 173045                                        Unknown           >0
# 173191                         Palestinian Extremists            0
# 173512                                        Taliban           >0
# 173531                                        Taliban            0
#
#         nwound_group
# 1415               0
# 1835               0
# 1906               0
# 4663              >0
# 4679              >0
# ...              ...
# 172732             0
# 173045             0
# 173191             0
# 173512             0
# 173531             0
#
# [1869 rows x 24 columns]

# %%
df[df['natlty1_txt'].isnull()].groupby('targtype1_txt').size()
# Out:
# targtype1_txt
# Airports & Aircraft                  3
# Business                            61
# Educational Institution              4
# Food or Water Supply                 2
# Government (Diplomatic)             11
# Government (General)                10
# Journalists & Media                  8
# Maritime                             4
# Military                             5
# NGO                                 14
# Police                               5
# Private Citizens & Property        230
# Religious Figures/Institutions      15
# Telecommunication                    2
# Terrorists/Non-State Militia         2
# Tourists                            12
# Transportation                      22
# Unknown                           1453
# Utilities                            4
# Violent Political Party              2
# dtype: int64

# %% [markdown]
# ### **타겟 대상이 unknown인 경우 natlty도 unknown으로 대체**

# %%
df.loc[df['targtype1_txt'] == 'Unknown', 'natlty1_txt'] = 'Unknown'

# %%
df[df['natlty1_txt'].isnull()].groupby('targtype1_txt').size()
# Out:
# targtype1_txt
# Airports & Aircraft                 3
# Business                           61
# Educational Institution             4
# Food or Water Supply                2
# Government (Diplomatic)            11
# Government (General)               10
# Journalists & Media                 8
# Maritime                            4
# Military                            5
# NGO                                14
# Police                              5
# Private Citizens & Property       230
# Religious Figures/Institutions     15
# Telecommunication                   2
# Terrorists/Non-State Militia        2
# Tourists                           12
# Transportation                     22
# Utilities                           4
# Violent Political Party             2
# dtype: int64

# %% [markdown]
# ### **테러 발생 국가와 natlty가 동일한지 아닌지 각 경우를 파악**

# %%
# 사건 발생 국가와 공격 대상 국적이 같은지 여부를 나타내는 새로운 컬럼 생성
df['nation_match'] = df['country_txt'] == df['natlty1_txt']

# 각 타겟유형별로 nation_match의 값(참/거짓) 빈도수를 확인
result = df.groupby('targtype1_txt')['nation_match'].value_counts()

display(result)
# Out:
# targtype1_txt                   nation_match
# Abortion Related                True              162
#                                 False               1
# Airports & Aircraft             True              614
#                                 False             126
# Business                        True            13217
#                                 False            1894
# Educational Institution         True             3845
#                                 False             122
# Food or Water Supply            True              231
#                                 False              10
# Government (Diplomatic)         False            2097
#                                 True              223
# Government (General)            True            18638
#                                 False             461
# Journalists & Media             True             2131
#                                 False             248
# Maritime                        True              190
#                                 False             105
# Military                        True            25053
#                                 False            3705
# NGO                             False             575
#                                 True              460
# Other                           True              145
#                                 False              47
# Police                          True            24145
#                                 False             747
# Private Citizens & Property     True            43817
#                                 False            2972
# Religious Figures/Institutions  True             4175
#                                 False             448
# Telecommunication               True              979
#                                 False              17
# Terrorists/Non-State Militia    True             3399
#                                 False             129
# Tourists                        False             241
#                                 True              123
# Transportation                  True             5035
#                                 False             239
# Unknown                         False            7043
# Utilities                       True             3869
#                                 False              79
# Violent Political Party         True             1794
#                                 False              46
# Name: count, dtype: int64

# %%
result_pct = df.groupby('targtype1_txt')['nation_match'].value_counts(normalize=True).mul(100).round(2)
display(result_pct)
# Out:
# targtype1_txt                   nation_match
# Abortion Related                True             99.39
#                                 False             0.61
# Airports & Aircraft             True             82.97
#                                 False            17.03
# Business                        True             87.47
#                                 False            12.53
# Educational Institution         True             96.92
#                                 False             3.08
# Food or Water Supply            True             95.85
#                                 False             4.15
# Government (Diplomatic)         False            90.39
#                                 True              9.61
# Government (General)            True             97.59
#                                 False             2.41
# Journalists & Media             True             89.58
#                                 False            10.42
# Maritime                        True             64.41
#                                 False            35.59
# Military                        True             87.12
#                                 False            12.88
# NGO                             False            55.56
#                                 True             44.44
# Other                           True             75.52
#                                 False            24.48
# Police                          True             97.00
#                                 False             3.00
# Private Citizens & Property     True             93.65
#                                 False             6.35
# Religious Figures/Institutions  True             90.31
#                                 False             9.69
# Telecommunication               True             98.29
#                                 False             1.71
# Terrorists/Non-State Militia    True             96.34
#                                 False             3.66
# Tourists                        False            66.21
#                                 True             33.79
# Transportation                  True             95.47
#                                 False             4.53
# Unknown                         False           100.00
# Utilities                       True             98.00
#                                 False             2.00
# Violent Political Party         True             97.50
#                                 False             2.50
# Name: proportion, dtype: float64

# %% [markdown]
# ### country = natlty 경우가 97% 이상인 타겟 유형만 natlty의 결측치를 country로 대체

# %%
# 1. 그룹별로 nation_match True 비율 계산 (퍼센트 단위)
result_pct = df.groupby('targtype1_txt')['nation_match'].value_counts(normalize=True).mul(100).round(2)

# 2. True 비율만 추출 (MultiIndex의 nation_match 레벨에서 True 값 선택)
true_pct = result_pct.xs(True, level='nation_match')

# 3. True 비율이 97% 이상인 범주의 리스트 생성
categories_high = true_pct[true_pct >= 97].index.tolist()
print("True 비율이 97% 이상인 범주:", categories_high)

# 4. 결측치(또는 NaN)인 'country' 컬럼만 업데이트:
mask_update = df['targtype1_txt'].isin(categories_high) & df['country_txt'].isna()
df.loc[mask_update, 'country_txt'] = 'natlty1_txt'
# Out:
# True 비율이 97% 이상인 범주: ['Abortion Related', 'Government (General)', 'Police', 'Telecommunication', 'Utilities', 'Violent Political Party']

# %%
df[columns_to_extract].isnull().sum()
# Out:
# eventid               0
# iyear                 0
# imonth                0
# iday                  0
# success               0
# country_txt           0
# region_txt            0
# provstate             0
# city                427
# latitude           2531
# longitude          2532
# attacktype1_txt       0
# targtype1_txt         0
# natlty1_txt         416
# weaptype1_txt         0
# nkill                 0
# nwound                0
# gname                 0
# dtype: int64

# %%
# 'coutry' 컬럼의 결측치를 "unknown"으로 채움
df['natlty1_txt'] = df['natlty1_txt'].fillna('Unknown')

# %%
df[columns_to_extract].isnull().sum()
# Out:
# eventid               0
# iyear                 0
# imonth                0
# iday                  0
# success               0
# country_txt           0
# region_txt            0
# provstate             0
# city                427
# latitude           2531
# longitude          2532
# attacktype1_txt       0
# targtype1_txt         0
# natlty1_txt           0
# weaptype1_txt         0
# nkill                 0
# nwound                0
# gname                 0
# dtype: int64

# %% [markdown]
# ## prov

# %%
# provstate와 city의 값을 소문자로 변환한 후 동일한지 비교하여 필터링
same_values = df[df['provstate'].str.lower() == df['city'].str.lower()]

print("provstate와 city가 동일한 경우 건수:", len(same_values))
display(same_values[columns_to_extract].head(25))
# Out:
# provstate와 city가 동일한 경우 건수: 29417
#           eventid  iyear  imonth  iday  success country_txt  \
# 0    199001000001   1990       1     0        1     Lebanon
# 4    199001010004   1990       1     1        1     Bolivia
# 6    199001010006   1990       1     1        0      Israel
# 7    199001010007   1990       1     1        1     Bolivia
# 22   199001030006   1990       1     3        0      Israel
# 47   199001060011   1990       1     6        1    Colombia
# 49   199001060013   1990       1     6        1    Colombia
# 53   199001070003   1990       1     7        1       Japan
# 66   199001080006   1990       1     8        0       Japan
# 67   199001080007   1990       1     8        1       Japan
# 68   199001080008   1990       1     8        1        Peru
# 74   199001090001   1990       1     9        1      Angola
# 78   199001090005   1990       1     9        1        Peru
# 93   199001100012   1990       1    10        1   Argentina
# 98   199001100017   1990       1    10        1      Poland
# 102  199001110004   1990       1    11        1     Bolivia
# 113  199001130002   1990       1    13        1    Zimbabwe
# 127  199001140008   1990       1    14        1      Cyprus
# 129  199001140010   1990       1    14        1      Turkey
# 133  199001150005   1990       1    15        0      Israel
# 135  199001150007   1990       1    15        1        Peru
# 140  199001160003   1990       1    16        1    Zimbabwe
# 142  199001160005   1990       1    16        1     Algeria
# 158  199001170005   1990       1    17        1     Bolivia
# 165  199001180006   1990       1    18        0       Japan
#
#                      region_txt     provstate          city   latitude  \
# 0    Middle East & North Africa        Beirut        Beirut  33.888523
# 4                 South America    Cochabamba    Cochabamba -17.382789
# 6    Middle East & North Africa      Tel Aviv      Tel Aviv  32.082970
# 7                 South America    Santa Cruz    Santa Cruz -17.783219
# 22   Middle East & North Africa     Jerusalem     Jerusalem  31.771599
# 47                South America        Bogota        Bogota   4.667128
# 49                South America        Bogota        Bogota   4.667128
# 53                    East Asia          Nara          nara  34.685087
# 66                    East Asia         Kyoto         Kyoto  35.011636
# 67                    East Asia         Tokyo         Tokyo  35.689125
# 68                South America          Lima          Lima -11.967368
# 74           Sub-Saharan Africa        Luanda        Luanda  -8.838837
# 78                South America          Lima          Lima -11.967368
# 93                South America  Buenos Aires  Buenos Aires -34.617680
# 98               Eastern Europe        Warsaw        Warsaw  52.229676
# 102               South America        La Paz        La Paz -16.509317
# 113          Sub-Saharan Africa       Unknown       Unknown        NaN
# 127              Western Europe       Unknown       Unknown        NaN
# 129  Middle East & North Africa        Ankara        Ankara  39.930771
# 133  Middle East & North Africa     Jerusalem     Jerusalem  31.771599
# 135               South America          Lima          Lima -11.967368
# 140          Sub-Saharan Africa       Unknown       Unknown        NaN
# 142  Middle East & North Africa         Blida         Blida  36.480453
# 158               South America        La Paz        La Paz -16.509317
# 165                   East Asia      Nagasaki      Nagasaki  32.750286
#
#       longitude                 attacktype1_txt  \
# 0     35.503513     Hostage Taking (Kidnapping)
# 4    -66.166439               Bombing/Explosion
# 6     34.811886                   Assassination
# 7    -63.182042               Bombing/Explosion
# 22    35.203400                   Assassination
# 47   -74.106056               Bombing/Explosion
# 49   -74.106056               Bombing/Explosion
# 53   135.805000  Facility/Infrastructure Attack
# 66   135.768029               Bombing/Explosion
# 67   139.747742               Bombing/Explosion
# 68   -76.978462                   Assassination
# 74    13.235582               Bombing/Explosion
# 78   -76.978462                   Assassination
# 93   -58.444435               Bombing/Explosion
# 98    21.012229               Bombing/Explosion
# 102  -68.104340               Bombing/Explosion
# 113         NaN               Bombing/Explosion
# 127         NaN                   Assassination
# 129   32.767540               Bombing/Explosion
# 133   35.203400                   Assassination
# 135  -76.978462               Bombing/Explosion
# 140         NaN               Bombing/Explosion
# 142    2.833880                   Armed Assault
# 158  -68.104340               Bombing/Explosion
# 165  129.877667                   Assassination
#
#                       targtype1_txt    natlty1_txt weaptype1_txt  nkill  \
# 0               Journalists & Media        Lebanon      Firearms    0.0
# 4    Religious Figures/Institutions  United States    Explosives    0.0
# 6              Government (General)         Israel    Explosives    0.0
# 7                          Business  United States    Explosives    0.0
# 22      Private Citizens & Property         Israel    Explosives    0.0
# 47             Government (General)       Colombia    Explosives    0.0
# 49                         Business       Colombia    Explosives    0.0
# 53             Government (General)          Japan    Incendiary    0.0
# 66             Government (General)          Japan    Explosives    0.0
# 67             Government (General)          Japan    Explosives    0.0
# 68                           Police           Peru      Firearms    2.0
# 74                           Police         Angola    Explosives    0.0
# 78                         Military           Peru      Firearms    1.0
# 93             Government (General)      Argentina    Explosives    0.0
# 98                         Business  United States    Explosives    0.0
# 102            Government (General)        Bolivia    Explosives    0.0
# 113                       Utilities  Great Britain    Explosives    0.0
# 127            Government (General)         Cyprus    Explosives    0.0
# 129         Government (Diplomatic)   Saudi Arabia    Explosives    0.0
# 133                        Military         Israel         Melee    0.0
# 135                        Military  United States    Explosives    0.0
# 140                       Utilities  Great Britain    Explosives    0.0
# 142            Government (General)        Algeria      Firearms    3.0
# 158            Government (General)        Bolivia    Explosives    0.0
# 165            Government (General)          Japan      Firearms    0.0
#
#      nwound                                          gname
# 0       0.0                                        Unknown
# 4       0.0                                 Alejo Calatayu
# 6       0.0                                        Unknown
# 7       0.0                                        Unknown
# 22      0.0                                        Unknown
# 47      2.0                              The Extraditables
# 49      3.0                                        Unknown
# 53      0.0                                  Nara Red Army
# 66      0.0                Chukakuha (Middle Core Faction)
# 67      0.0                Chukakuha (Middle Core Faction)
# 68      0.0                              Shining Path (SL)
# 74      3.0                                        Unknown
# 78      0.0                              Shining Path (SL)
# 93      0.0                                        Unknown
# 98      0.0                                        Unknown
# 102     0.0       Zarate Willka Armed Forces of Liberation
# 113     0.0  Mozambique National Resistance Movement (MNR)
# 127     0.0                                        Unknown
# 129     0.0                                      Hezbollah
# 133     1.0                                   Palestinians
# 135     0.0      Tupac Amaru Revolutionary Movement (MRTA)
# 140     0.0  Mozambique National Resistance Movement (MNR)
# 142     1.0                         Muslim Fundamentalists
# 158     1.0                                        Unknown
# 165     0.0                                      Seikijuku

# %%
# provstate, city 컬럼의 값을 모두 소문자로 변환하여 비교
provstate_unknown = df[df['provstate'].str.lower() == 'unknown']
city_unknown = df[df['city'].str.lower() == 'unknown']
both_unknown = df[(df['provstate'].str.lower() == 'unknown') & (df['city'].str.lower() == 'unknown')]

print("provstate가 Unknown인 경우의 건수:", len(provstate_unknown))
print("city가 Unknown인 경우의 건수:", len(city_unknown))
print("provstate와 city 모두 Unknown인 경우의 건수:", len(both_unknown))
# Out:
# provstate가 Unknown인 경우의 건수: 2498
# city가 Unknown인 경우의 건수: 8843
# provstate와 city 모두 Unknown인 경우의 건수: 1640

# %%
# provstate가 "Unknown"이면서, city는 "Unknown"이 아닌 경우 필터링
provstate_unknown_city_not = df[(df['provstate'].str.lower() == 'unknown') & (df['city'].str.lower() != 'unknown')]

# 데이터 출력
print("provstate가 Unknown이고, city는 Unknown이 아닌 경우 건수:", len(provstate_unknown_city_not))
display(provstate_unknown_city_not[columns_to_extract].head())
# Out:
# provstate가 Unknown이고, city는 Unknown이 아닌 경우 건수: 858
#          eventid  iyear  imonth  iday  success country_txt     region_txt  \
# 9   199001020002   1990       1     2        1        Peru  South America
# 13  199001020006   1990       1     2        1        Peru  South America
# 14  199001020007   1990       1     2        1        Peru  South America
# 36  199001050008   1990       1     5        1    Colombia  South America
# 37  199001060001   1990       1     6        1       India     South Asia
#
#    provstate         city  latitude  longitude  \
# 9    Unknown      Amnaija       NaN        NaN
# 13   Unknown      Amnaija       NaN        NaN
# 14   Unknown      Amnaija       NaN        NaN
# 36   Unknown  La Cuchilla       NaN        NaN
# 37   Unknown      Nahajia       NaN        NaN
#
#                    attacktype1_txt                targtype1_txt natlty1_txt  \
# 9                    Armed Assault                       Police        Peru
# 13                   Armed Assault         Government (General)        Peru
# 14  Facility/Infrastructure Attack         Government (General)        Peru
# 36               Bombing/Explosion                    Utilities    Colombia
# 37               Bombing/Explosion  Private Citizens & Property       India
#
#    weaptype1_txt  nkill  nwound                                       gname
# 9       Firearms    0.0     2.0                           Shining Path (SL)
# 13    Incendiary    0.0     0.0                           Shining Path (SL)
# 14    Incendiary    0.0     0.0                           Shining Path (SL)
# 36    Explosives    0.0     0.0  National Liberation Army of Colombia (ELN)
# 37    Explosives    0.0     0.0                                     Unknown

# %%
# provstate가 "unknown"이면서, city는 "unknown"이 아닌 행을 선택하는 마스크 생성
mask = (df['provstate'].str.lower() == 'unknown') & (df['city'].str.lower() != 'unknown')

# 해당 조건을 만족하는 행의 provstate 값을 city 값으로 대체
df.loc[mask, 'provstate'] = df.loc[mask, 'city']

# 결과 확인: 해당 조건을 만족하는 행들 미리보기
print("provstate 값이 city 값으로 대체된 결과:")
print(df.loc[mask, ['provstate', 'city']].head())
# Out:
# provstate 값이 city 값으로 대체된 결과:
#       provstate         city
# 9       Amnaija      Amnaija
# 13      Amnaija      Amnaija
# 14      Amnaija      Amnaija
# 36  La Cuchilla  La Cuchilla
# 37      Nahajia      Nahajia

# %%
# provstate, city 컬럼의 값을 모두 소문자로 변환하여 비교
provstate_unknown = df[df['provstate'].str.lower() == 'unknown']
city_unknown = df[df['city'].str.lower() == 'unknown']
both_unknown = df[(df['provstate'].str.lower() == 'unknown') & (df['city'].str.lower() == 'unknown')]

print("provstate가 Unknown인 경우의 건수:", len(provstate_unknown))
print("city가 Unknown인 경우의 건수:", len(city_unknown))
print("provstate와 city 모두 Unknown인 경우의 건수:", len(both_unknown))
# Out:
# provstate가 Unknown인 경우의 건수: 1640
# city가 Unknown인 경우의 건수: 8843
# provstate와 city 모두 Unknown인 경우의 건수: 1640

# %%
# city 컬럼의 결측치(NaN)를 "unknown"으로 대체
df['city'] = df['city'].fillna('Unknown')
print(df['city'].head())
# Out:
# 0        Beirut
# 1      Srinagar
# 2      Srinagar
# 3      Srinagar
# 4    Cochabamba
# Name: city, dtype: object

# %%
# provstate, city 컬럼의 값을 모두 소문자로 변환하여 비교
provstate_unknown = df[df['provstate'].str.lower() == 'unknown']
city_unknown = df[df['city'].str.lower() == 'unknown']
both_unknown = df[(df['provstate'].str.lower() == 'unknown') & (df['city'].str.lower() == 'unknown')]

print("provstate가 Unknown인 경우의 건수:", len(provstate_unknown))
print("city가 Unknown인 경우의 건수:", len(city_unknown))
print("provstate와 city 모두 Unknown인 경우의 건수:", len(both_unknown))
# Out:
# provstate가 Unknown인 경우의 건수: 1640
# city가 Unknown인 경우의 건수: 9270
# provstate와 city 모두 Unknown인 경우의 건수: 1640

# %%
# provstate 또는 city가 "unknown"인 행 선택 (소문자 비교)
mask_unknown = (df['provstate'].str.lower() == 'unknown') | (df['city'].str.lower() == 'unknown')

# 위경도 데이터가 존재하는 행 선택 (NaN이 아닌 경우)
mask_latlon = df['latitude'].notna() & df['longitude'].notna()

# 두 조건을 모두 만족하는 행 필터링
df_unknown_with_latlon = df[mask_unknown & mask_latlon]

print("위경도 데이터가 있는, provstate 또는 city가 'unknown'인 경우의 건수:", len(df_unknown_with_latlon))
print(df_unknown_with_latlon.head())
# Out:
# 위경도 데이터가 있는, provstate 또는 city가 'unknown'인 경우의 건수: 7623
#      Unnamed: 0       eventid  iyear  imonth  iday country_txt     region_txt  \
# 8         41077  199001020001   1990       1     2    Colombia  South America
# 18        41087  199001030002   1990       1     3    Colombia  South America
# 25        41094  199001040001   1990       1     4        Peru  South America
# 104       41173  199001110006   1990       1    11        Peru  South America
# 126       41195  199001140007   1990       1    14   Sri Lanka     South Asia
#
#            provstate   latitude  longitude  ... weaptype1_txt  nkill nkillter  \
# 8       Cundinamarca   5.026003 -74.030012  ...      Firearms    0.0      NaN
# 18   Valle del Cauca   3.800889 -76.641271  ...      Firearms    3.0      NaN
# 25        San Martin  -7.244488 -76.825965  ...      Firearms    3.0      NaN
# 104            Junin -11.161067 -75.993090  ...    Explosives    0.0      NaN
# 126          Central   7.256500  80.721442  ...      Firearms    8.0      NaN
#
#     nwound nwoundte natlty1_txt  \
# 8      0.0      NaN    Colombia
# 18    20.0      NaN    Colombia
# 25     1.0      NaN        Peru
# 104    0.0      NaN        Peru
# 126    0.0      NaN   Sri Lanka
#
#                                              gname  nkill_group  nwound_group  \
# 8    Revolutionary Armed Forces of Colombia (FARC)            0             0
# 18      National Liberation Army of Colombia (ELN)           >0            >0
# 25                               Shining Path (SL)           >0            >0
# 104                              Shining Path (SL)            0             0
# 126                                Vigilante Group           >0             0
#
#      nation_match
# 8            True
# 18           True
# 25           True
# 104          True
# 126          True
#
# [5 rows x 25 columns]
